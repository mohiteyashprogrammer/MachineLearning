# %%
from sklearn.datasets import load_iris
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV

# %%
data = load_iris()

# %%
X_train,X_test,y_train,y_test =train_test_split(data.data,data.target,test_size=0.20,random_state=32)

# %%
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (120, 4)
# (120,)
# (30, 4)
# (30,)

# %%
tree = DecisionTreeClassifier()

# %%
tree.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
tree.score(X_train,y_train)
# Out:
# 1.0

# %%
ypredict = tree.predict(X_test)

# %%
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report
accuracy_score(y_test,ypredict)
# Out:
# 0.9666666666666667

# %%
param_grid = {
    "criterion":['gini',"entropy","log_loss"],
    "splitter":['best','random'],
    "max_depth":[3,4,5,6],
    "min_samples_split":[2,3,4,5],
    "min_samples_leaf":[1,2,3],
    "max_features":["auto","sqrt","log2"]
}

# %%
tree1 = DecisionTreeClassifier()
grid_search = GridSearchCV(estimator=tree1,param_grid=param_grid,cv=5,scoring="accuracy")

# %%
grid_search.fit(X_train,y_train)
# Out:
# C:\Users\yash mohite\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\tree\_classes.py:298: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'`.
#   warnings.warn(
# C:\Users\yash mohite\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\tree\_classes.py:298: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'`.
#   warnings.warn(
# C:\Users\yash mohite\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\tree\_classes.py:298: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'`.
#   warnings.warn(
# ...

# %%
grid_search.best_estimator_
# Out:
# DecisionTreeClassifier(max_depth=4, max_features='auto', min_samples_split=4)

# %%
grid_search.best_params_
# Out:
# {'criterion': 'gini',
#  'max_depth': 4,
#  'max_features': 'auto',
#  'min_samples_leaf': 1,
#  'min_samples_split': 4,
#  'splitter': 'best'}

# %%
grid_search.score(X_train,y_train)
# Out:
# 0.975

# %%
ypredict = grid_search.predict(X_test)

# %%
y_test
# Out:
# array([1, 0, 0, 1, 2, 2, 0, 0, 1, 0, 1, 2, 1, 1, 2, 2, 1, 2, 1, 0, 0, 2,
#        2, 0, 0, 1, 0, 2, 0, 0])

# %%
ypredict
# Out:
# array([1, 0, 0, 1, 1, 2, 0, 0, 1, 0, 1, 2, 1, 1, 2, 2, 1, 2, 1, 0, 0, 2,
#        1, 0, 0, 1, 0, 2, 0, 0])

# %%
accuracy_score(y_test,ypredict)
# Out:
# 0.9333333333333333

# %%
confusion_matrix(y_test,ypredict)
# Out:
# array([[12,  0,  0],
#        [ 0,  9,  0],
#        [ 0,  2,  7]], dtype=int64)

# %%
print(classification_report(ypredict,y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        12
#            1       1.00      0.82      0.90        11
#            2       0.78      1.00      0.88         7
#
#     accuracy                           0.93        30
#    macro avg       0.93      0.94      0.92        30
# weighted avg       0.95      0.93      0.93        30

# %%
# import matplotlib.pyplot as plt
# from sklearn import tree
# plt.figure(figsize=(15,10))
# tree.plot_tree(tree,filled=True)

# %%
from sklearn.datasets import load_diabetes
from sklearn.model_selection import cross_val_score
from sklearn.tree import DecisionTreeRegressor

# %%
X, y = load_diabetes(return_X_y=True)

# %%
X
# Out:
# array([[ 0.03807591,  0.05068012,  0.06169621, ..., -0.00259226,
#          0.01990749, -0.01764613],
#        [-0.00188202, -0.04464164, -0.05147406, ..., -0.03949338,
#         -0.06833155, -0.09220405],
#        [ 0.08529891,  0.05068012,  0.04445121, ..., -0.00259226,
#          0.00286131, -0.02593034],
#        ...,
#        [ 0.04170844,  0.05068012, -0.01590626, ..., -0.01107952,
#         -0.04688253,  0.01549073],
#        [-0.04547248, -0.04464164,  0.03906215, ...,  0.02655962,
#          0.04452873, -0.02593034],
#        [-0.04547248, -0.04464164, -0.0730303 , ..., -0.03949338,
#         -0.00422151,  0.00306441]])

# %%
y
# Out:
# array([151.,  75., 141., 206., 135.,  97., 138.,  63., 110., 310., 101.,
#         69., 179., 185., 118., 171., 166., 144.,  97., 168.,  68.,  49.,
#         68., 245., 184., 202., 137.,  85., 131., 283., 129.,  59., 341.,
#         87.,  65., 102., 265., 276., 252.,  90., 100.,  55.,  61.,  92.,
#        259.,  53., 190., 142.,  75., 142., 155., 225.,  59., 104., 182.,
#        128.,  52.,  37., 170., 170.,  61., 144.,  52., 128.,  71., 163.,
#        150.,  97., 160., 178.,  48., 270., 202., 111.,  85.,  42., 170.,
#        200., 252., 113., 143.,  51.,  52., 210.,  65., 141.,  55., 134.,
#         42., 111.,  98., 164.,  48.,  96.,  90., 162., 150., 279.,  92.,
#         83., 128., 102., 302., 198.,  95.,  53., 134., 144., 232.,  81.,
#        104.,  59., 246., 297., 258., 229., 275., 281., 179., 200., 200.,
#        173., 180.,  84., 121., 161.,  99., 109., 115., 268., 274., 158.,
#        107.,  83., 103., 272.,  85., 280., 336., 281., 118., 317., 235.,
# ...

# %%
print(classification_report(ypredict,y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        12
#            1       1.00      0.82      0.90        11
#            2       0.78      1.00      0.88         7
#
#     accuracy                           0.93        30
#    macro avg       0.93      0.94      0.92        30
# weighted avg       0.95      0.93      0.93        30
